# %%
# !pip install -r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt
# Out:
# Collecting blobfile>=3.0.0 (from -r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 1))
#   Downloading blobfile-3.2.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: huggingface_hub>=0.24.7 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from -r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 2)) (1.4.1)
# Requirement already satisfied: ipywidgets>=8.1.2 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from -r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 3)) (8.1.3)
# Collecting safetensors>=0.4.4 (from -r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 4))
#   Using cached safetensors-0.7.0-cp38-abi3-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Requirement already satisfied: sentencepiece>=0.1.99 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from -r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 5)) (0.2.0)
# Collecting pycryptodomex>=3.8 (from blobfile>=3.0.0->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 1))
#   Downloading pycryptodomex-3.23.0-cp37-abi3-macosx_10_9_universal2.whl.metadata (3.4 kB)
# Requirement already satisfied: urllib3>=2 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from blobfile>=3.0.0->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 1)) (2.4.0)
# Requirement already satisfied: lxml>=4.9 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from blobfile>=3.0.0->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 1)) (5.3.1)
# Requirement already satisfied: filelock>=3.0 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from blobfile>=3.0.0->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 1)) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from huggingface_hub>=0.24.7->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 2)) (2023.9.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from huggingface_hub>=0.24.7->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 2)) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from huggingface_hub>=0.24.7->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 2)) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from huggingface_hub>=0.24.7->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 2)) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from huggingface_hub>=0.24.7->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 2)) (6.0.1)
# Requirement already satisfied: shellingham in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from huggingface_hub>=0.24.7->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 2)) (1.5.4)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from huggingface_hub>=0.24.7->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 2)) (4.66.4)
# Requirement already satisfied: typer-slim in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from huggingface_hub>=0.24.7->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 2)) (0.23.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from huggingface_hub>=0.24.7->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 2)) (4.15.0)
# Requirement already satisfied: anyio in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.24.7->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 2)) (4.12.1)
# Requirement already satisfied: certifi in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.24.7->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 2)) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.24.7->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 2)) (1.0.5)
# Requirement already satisfied: idna in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.24.7->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 2)) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub>=0.24.7->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 2)) (0.14.0)
# Requirement already satisfied: comm>=0.1.3 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from ipywidgets>=8.1.2->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 3)) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from ipywidgets>=8.1.2->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 3)) (8.26.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from ipywidgets>=8.1.2->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 3)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from ipywidgets>=8.1.2->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 3)) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from ipywidgets>=8.1.2->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 3)) (3.0.11)
# Requirement already satisfied: decorator in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 3)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 3)) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 3)) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 3)) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 3)) (2.18.0)
# Requirement already satisfied: stack-data in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 3)) (0.6.2)
# Requirement already satisfied: exceptiongroup in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 3)) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 3)) (4.9.0)
# Requirement already satisfied: wcwidth in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=8.1.2->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 3)) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.1.2->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 3)) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=8.1.2->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 3)) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.1.2->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 3)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.1.2->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 3)) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.1.2->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 3)) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets>=8.1.2->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 3)) (1.16.0)
# Requirement already satisfied: typer>=0.23.0 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from typer-slim->huggingface_hub>=0.24.7->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 2)) (0.23.0)
# Requirement already satisfied: click>=8.0.0 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from typer>=0.23.0->typer-slim->huggingface_hub>=0.24.7->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 2)) (8.1.7)
# Requirement already satisfied: rich>=10.11.0 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from typer>=0.23.0->typer-slim->huggingface_hub>=0.24.7->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 2)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from typer>=0.23.0->typer-slim->huggingface_hub>=0.24.7->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 2)) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from rich>=10.11.0->typer>=0.23.0->typer-slim->huggingface_hub>=0.24.7->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 2)) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/pbanavara/miniforge3/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.23.0->typer-slim->huggingface_hub>=0.24.7->-r https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/refs/heads/main/ch05/07_gpt_to_llama/requirements-extra.txt (line 2)) (0.1.2)
# Downloading blobfile-3.2.0-py3-none-any.whl (76 kB)
# Using cached safetensors-0.7.0-cp38-abi3-macosx_11_0_arm64.whl (447 kB)
# Downloading pycryptodomex-3.23.0-cp37-abi3-macosx_10_9_universal2.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 550.5 kB/s  0:00:04582.0 kB/s eta 0:00:01
# WARNING: Error parsing dependencies of google-auth: [Errno 2] No such file or directory: '/Users/pbanavara/miniforge3/lib/python3.10/site-packages/google_auth-2.40.3.dist-info/METADATA'
# Installing collected packages: safetensors, pycryptodomex, blobfile
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.4.3
#     Uninstalling safetensors-0.4.3:
#       Successfully uninstalled safetensors-0.4.3
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [blobfile]━━ 1/3 [pycryptodomex]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 4.40.2 requires huggingface-hub<1.0,>=0.19.3, but you have huggingface-hub 1.4.1 which is incompatible.
# Successfully installed blobfile-3.2.0 pycryptodomex-3.23.0 safetensors-0.7.0
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
from importlib.metadata import version

pkgs = [
    "huggingface_hub",  # to download pretrained weights
    "tokenizers",       # to implement the tokenizer
    "torch",            # to implement the model
]
for p in pkgs:
    print(f"{p} version: {version(p)}")
# Out:
# huggingface_hub version: 1.4.1
# tokenizers version: 0.19.1
# torch version: 2.10.0

# %%
USE_MODEL = "Qwen3.5-0.8B"

# %%
import torch
import torch.nn as nn


class FeedForward(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.fc1 = nn.Linear(cfg["emb_dim"], cfg["hidden_dim"], dtype=cfg["dtype"], bias=False)
        self.fc2 = nn.Linear(cfg["emb_dim"], cfg["hidden_dim"], dtype=cfg["dtype"], bias=False)
        self.fc3 = nn.Linear(cfg["hidden_dim"], cfg["emb_dim"], dtype=cfg["dtype"], bias=False)

    def forward(self, x):
        x_fc1 = self.fc1(x)
        x_fc2 = self.fc2(x)
        x = nn.functional.silu(x_fc1) * x_fc2
        return self.fc3(x)
